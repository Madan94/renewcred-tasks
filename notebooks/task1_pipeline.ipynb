# %% [markdown]
# # Task 1 — Ingestion, Data Quality, and EDA
#
# This notebook mirrors the script deliverable:
#
# - Parse raw MQTT CSV into the canonical 21-column telemetry frame
# - Generate the HTML data quality report
# - Generate EDA charts (PNG/HTML)
#
# Run the same pipeline as `python task1_pipeline.py`:

# %%
import runpy

runpy.run_path("task1_pipeline.py", run_name="__main__")
