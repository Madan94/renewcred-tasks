# %% [markdown]
# # Task 3 — GPS quality, Kalman smoothing, trips, carbon credits
#
# - Parse MQTT-derived frame → anomaly flags, per-device Kalman lat/lon smoothing
# - Folium map: **raw vs smoothed** polylines for two devices with the most GPS points
# - Trip segmentation → `trip_segments.csv`; **net tCO2e** → `trip_carbon_credits.csv`
#
# Run the same pipeline as `python task3_gps.py`:

# %%
import runpy

runpy.run_path("task3_gps.py", run_name="__main__")
